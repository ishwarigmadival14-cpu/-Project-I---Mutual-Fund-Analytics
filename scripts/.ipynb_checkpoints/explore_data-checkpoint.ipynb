# %%
import pandas as pd

df = pd.read_csv("data/raw/fund_master.csv")

print(df.columns.tolist())
# Out:
# ['date', 'nav', 'scheme_code', 'scheme_name', 'fund_name', 'fund_house', 'scheme_category']

# %%
print(df.columns)
# Out:
# Index(['date', 'nav', 'scheme_code', 'scheme_name', 'fund_name', 'fund_house',
#        'scheme_category'],
#       dtype='object')

# %%
df["scheme_category"]
# Out:
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#                      ...
# 3103                               NaN
# 3104                               NaN
# 3105                               NaN
# 3106                               NaN
# 3107    Equity Scheme - Small Cap Fund
# Name: scheme_category, Length: 3108, dtype: object

# %%
for col in df.columns:
    print(col)
# Out:
# date
# nav
# scheme_code
# scheme_name
# fund_name
# fund_house
# scheme_category

# %%
import pandas as pd

fund=pd.read_csv("data/raw/fund_master.csv")

print("Fund Houses")

print(fund["fund_house"].unique())

print()

print("Categories")

print(fund["scheme_category"].unique())

print()

print("Schema Code")

print(fund["scheme_code"].unique())
# Out:
# Fund Houses
# [nan 'SBI Mutual Fund']
#
# Categories
# [nan 'Equity Scheme - Small Cap Fund']
#
# Schema Code
# [125497]
